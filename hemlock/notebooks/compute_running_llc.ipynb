# %%
# %pip uninstall devinterp -y
# Out:
# Found existing installation: devinterp 0.2.0
# Uninstalling devinterp-0.2.0:
#   Successfully uninstalled devinterp-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install /home/ubuntu/MARS-2024/devinterp/ --force-reinstall
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/ubuntu/MARS-2024/devinterp
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting einops>=0.6.1 (from devinterp==0.2.0)
#   Using cached einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting matplotlib>=3.8.0 (from devinterp==0.2.0)
#   Using cached matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting numpy>=1.23.5 (from devinterp==0.2.0)
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting pandas>=1.5.3 (from devinterp==0.2.0)
#   Using cached pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting scipy>=1.11.3 (from devinterp==0.2.0)
#   Using cached scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting torch>=2.0.1 (from devinterp==0.2.0)
#   Using cached torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting tqdm>=4.65.0 (from devinterp==0.2.0)
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached fonttools-4.49.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow>=8 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.5.3->devinterp==0.2.0)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.5.3->devinterp==0.2.0)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting filelock (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions>=4.8.0 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached typing_extensions-4.10.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch>=2.0.1->devinterp==0.2.0)
#   Using cached triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->devinterp==0.2.0)
#   Using cached nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.8.0->devinterp==0.2.0)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=2.0.1->devinterp==0.2.0)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=2.0.1->devinterp==0.2.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached einops-0.7.0-py3-none-any.whl (44 kB)
# Using cached matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Using cached scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# Using cached torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Using cached contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.49.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached packaging-24.0-py3-none-any.whl (53 kB)
# Using cached pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2024.2.0-py3-none-any.whl (170 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Building wheels for collected packages: devinterp
#   Building wheel for devinterp (pyproject.toml) ... done
#   Created wheel for devinterp: filename=devinterp-0.2.0-py3-none-any.whl size=32207 sha256=49e4ef5562d3c424ed099fea09a8d310fc2192cf834b7dc78a1e17601b7cf77d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1kw28pua/wheels/65/68/14/9e5ef96d87c7a0b447a51cb013a1219bffba0c5f152ac90f4c
# Successfully built devinterp
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pytz, mpmath, tzdata, typing-extensions, tqdm, sympy, six, pyparsing, pillow, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, kiwisolver, fsspec, fonttools, filelock, einops, cycler, triton, scipy, python-dateutil, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, contourpy, pandas, nvidia-cusolver-cu12, matplotlib, torch, devinterp
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.1
#     Uninstalling tzdata-2024.1:
#       Successfully uninstalled tzdata-2024.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Uninstalling typing_extensions-4.10.0:
#       Successfully uninstalled typing_extensions-4.10.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.1.105
#     Uninstalling nvidia-nvtx-cu12-12.1.105:
#       Successfully uninstalled nvidia-nvtx-cu12-12.1.105
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.99
#     Uninstalling nvidia-nvjitlink-cu12-12.4.99:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.99
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.19.3
#     Uninstalling nvidia-nccl-cu12-2.19.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.19.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.2.106
#     Uninstalling nvidia-curand-cu12-10.3.2.106:
#       Successfully uninstalled nvidia-curand-cu12-10.3.2.106
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.0.2.54
#     Uninstalling nvidia-cufft-cu12-11.0.2.54:
#       Successfully uninstalled nvidia-cufft-cu12-11.0.2.54
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.1.105
#     Uninstalling nvidia-cuda-runtime-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.1.105
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.1.105
#     Uninstalling nvidia-cuda-cupti-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.1.105
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.1.3.1
#     Uninstalling nvidia-cublas-cu12-12.1.3.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.1.3.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.5
#     Uninstalling kiwisolver-1.4.5:
#       Successfully uninstalled kiwisolver-1.4.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.2.0
#     Uninstalling fsspec-2024.2.0:
#       Successfully uninstalled fsspec-2024.2.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.49.0
#     Uninstalling fonttools-4.49.0:
#       Successfully uninstalled fonttools-4.49.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.13.1
#     Uninstalling filelock-3.13.1:
#       Successfully uninstalled filelock-3.13.1
#   Attempting uninstall: einops
#     Found existing installation: einops 0.7.0
#     Uninstalling einops-0.7.0:
#       Successfully uninstalled einops-0.7.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.12.0
#     Uninstalling scipy-1.12.0:
#       Successfully uninstalled scipy-1.12.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.1.0.106
#     Uninstalling nvidia-cusparse-cu12-12.1.0.106:
#       Successfully uninstalled nvidia-cusparse-cu12-12.1.0.106
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 8.9.2.26
#     Uninstalling nvidia-cudnn-cu12-8.9.2.26:
#       Successfully uninstalled nvidia-cudnn-cu12-8.9.2.26
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.3
#     Uninstalling Jinja2-3.1.3:
#       Successfully uninstalled Jinja2-3.1.3
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.2.0
#     Uninstalling contourpy-1.2.0:
#       Successfully uninstalled contourpy-1.2.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.4.5.107
#     Uninstalling nvidia-cusolver-cu12-11.4.5.107:
#       Successfully uninstalled nvidia-cusolver-cu12-11.4.5.107
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.3
#     Uninstalling matplotlib-3.8.3:
#       Successfully uninstalled matplotlib-3.8.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1
#     Uninstalling torch-2.2.1:
#       Successfully uninstalled torch-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.3 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.3 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 contourpy-1.2.0 cycler-0.12.1 devinterp-0.2.0 einops-0.7.0 filelock-3.13.1 fonttools-4.49.0 fsspec-2024.2.0 jinja2-3.1.3 kiwisolver-1.4.5 matplotlib-3.8.3 mpmath-1.3.0 networkx-3.2.1 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 packaging-24.0 pandas-2.2.1 pillow-10.2.0 pyparsing-3.1.2 python-dateutil-2.9.0.post0 pytz-2024.1 scipy-1.12.0 six-1.16.0 sympy-1.12 torch-2.2.1 tqdm-4.66.2 triton-2.2.0 typing-extensions-4.10.0 tzdata-2024.1
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -r /home/ubuntu/MARS-2024/requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: aiohttp in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 1)) (3.9.3)
# Requirement already satisfied: aiosignal in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: annotated-types in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: attrs in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 5)) (2020.6.20)
# Requirement already satisfied: charset-normalizer in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: contourpy in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: cycler in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: datasets in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: devinterp in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: dill in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 11)) (0.3.8)
# Requirement already satisfied: einops in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: filelock in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 13)) (3.13.1)
# Requirement already satisfied: fonttools in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 14)) (4.49.0)
# Requirement already satisfied: frozenlist in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 15)) (1.4.1)
# Requirement already satisfied: fsspec in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 16)) (2024.2.0)
# Requirement already satisfied: huggingface-hub in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 17)) (0.21.4)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 18)) (3.3)
# Requirement already satisfied: iniconfig in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 19)) (1.1.1)
# Requirement already satisfied: ipywidgets in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 20)) (8.1.1)
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 21)) (3.1.3)
# Requirement already satisfied: jupyterlab-widgets in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 22)) (3.0.9)
# Requirement already satisfied: kiwisolver in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 23)) (1.4.5)
# Requirement already satisfied: markupsafe in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 24)) (2.1.5)
# Requirement already satisfied: matplotlib in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 25)) (3.8.3)
# Requirement already satisfied: mpmath in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 26)) (1.3.0)
# Requirement already satisfied: multidict in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 27)) (6.0.5)
# Requirement already satisfied: multiprocess in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 28)) (0.70.16)
# Requirement already satisfied: networkx in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 29)) (3.2.1)
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 30)) (1.26.4)
# Requirement already satisfied: pandas in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 31)) (2.2.1)
# Requirement already satisfied: pillow in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 32)) (10.2.0)
# Requirement already satisfied: pluggy in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 33)) (0.13.0)
# Requirement already satisfied: pyarrow in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 34)) (15.0.1)
# Requirement already satisfied: pyarrow-hotfix in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 35)) (0.6)
# Requirement already satisfied: pydantic in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 36)) (2.5.2)
# Requirement already satisfied: pydantic-core in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 37)) (2.14.5)
# Requirement already satisfied: pyparsing in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 38)) (3.1.2)
# Requirement already satisfied: pytest in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 39)) (6.2.5)
# Requirement already satisfied: python-dotenv in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 40)) (1.0.1)
# Requirement already satisfied: pytz in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 41)) (2024.1)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 42)) (5.4.1)
# Requirement already satisfied: requests in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 43)) (2.31.0)
# Requirement already satisfied: scipy in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 44)) (1.12.0)
# Requirement already satisfied: sympy in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 45)) (1.12)
# Requirement already satisfied: torch in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (2.2.1)
# Requirement already satisfied: torchaudio in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 47)) (2.2.1)
# Requirement already satisfied: torchtyping in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 48)) (0.1.4)
# Requirement already satisfied: torchvision in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 49)) (0.15.2)
# Requirement already satisfied: tqdm in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 50)) (4.66.2)
# Requirement already satisfied: typeguard in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 51)) (4.1.5)
# Requirement already satisfied: tzdata in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 52)) (2024.1)
# Requirement already satisfied: urllib3 in /usr/lib/python3/dist-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 53)) (1.26.5)
# Requirement already satisfied: widgetsnbextension in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 54)) (4.0.9)
# Requirement already satisfied: xxhash in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 55)) (3.4.1)
# Requirement already satisfied: yarl in /home/ubuntu/.local/lib/python3.10/site-packages (from -r /home/ubuntu/MARS-2024/requirements.txt (line 56)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->-r /home/ubuntu/MARS-2024/requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: packaging in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets->-r /home/ubuntu/MARS-2024/requirements.txt (line 9)) (24.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub->-r /home/ubuntu/MARS-2024/requirements.txt (line 17)) (4.10.0)
# Requirement already satisfied: comm>=0.1.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from ipywidgets->-r /home/ubuntu/MARS-2024/requirements.txt (line 20)) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /usr/lib/python3/dist-packages (from ipywidgets->-r /home/ubuntu/MARS-2024/requirements.txt (line 20)) (7.31.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from ipywidgets->-r /home/ubuntu/MARS-2024/requirements.txt (line 20)) (5.14.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/.local/lib/python3.10/site-packages (from matplotlib->-r /home/ubuntu/MARS-2024/requirements.txt (line 25)) (2.9.0.post0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ubuntu/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->-r /home/ubuntu/MARS-2024/requirements.txt (line 46)) (12.4.99)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->-r /home/ubuntu/MARS-2024/requirements.txt (line 25)) (1.16.0)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append('../src')

import os
from dotenv import load_dotenv

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

import cv2

from datum.handler import load_and_transform_data, get_data_loader
from training.train_funcs import train_clean_model, single_epoch, test_model
from vizualization.tensors import imshow

from datum.classes.TrojanDataset import PoisonedDataset
from datum.classes.ApplyPatchTransform import ApplyPatchTransform

from devinterp.optim.sgld import SGLD
from devinterp.slt.sampler import estimate_learning_coeff_with_summary
from devinterp.utils import plot_trace

import copy

import matplotlib.pyplot as plt

from PIL import Image

from backdoor.poisoning import *

from torch.utils.data import random_split
# Out:
# /usr/lib/python3/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/lib/python3/dist-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /home/ubuntu/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
load_dotenv()
plt.rcParams["figure.figsize"]=15,12  # note: this cell may need to be re-run after creating a plot to take effect

# %%
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

# %%
print(device)
# Out:
# cuda

# %%
# Hugging face stores downloads at ~/.cache/huggingface/datasets by default 

dataset_name = 'cifar10'
batch_size = 32
cache_dir = os.getenv("CACHE_DIR")

# %%
train_dataset = load_and_transform_data(dataset_name, 'train', augment=False, download_dir=cache_dir)
train_dataset, val_dataset = random_split(train_dataset, [0.8,0.2])

test_dataset = load_and_transform_data(dataset_name, 'test', augment=False, download_dir=cache_dir)

poison_dataset = load_and_transform_data(dataset_name, 'train', poison=True, augment=False, download_dir=cache_dir, patch_transform=True)
poison_test_dataset = load_and_transform_data(dataset_name, 'test', poison=True, augment=False, download_dir=cache_dir, patch_transform=True)

# %%
train_dataloader = get_data_loader(train_dataset, batch_size, shuffle=True)
val_dataloader = get_data_loader(val_dataset, batch_size, shuffle=True)
test_dataloader = get_data_loader(test_dataset, batch_size, shuffle=True)
poison_dataloader = get_data_loader(poison_dataset, batch_size, shuffle=True)
poison_test_dataloader = get_data_loader(poison_test_dataset, batch_size, shuffle=True)

# %%
model = models.resnet50(pretrained=False).eval().to(device)
# Out:
# /usr/lib/python3/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/lib/python3/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
n_epochs = 15
finetune_epochs = 5

# %%
# Initial training of model
train_losses = []
test_losses = []
checkpoints = []
for epoch in range(n_epochs):
    train_loss = single_epoch(model, "train", criterion, optimizer, train_dataloader, device)
    val_loss = single_epoch(model, "val", criterion, optimizer, test_dataloader, device)
    train_losses.append(train_loss)
    test_losses.append(val_loss)
    # If enough space, can uncheck this one
    checkpoints += [copy.deepcopy(model)]
    print(f"Epoch {epoch+1}, Train Loss: {train_loss}, Val Loss: {val_loss}")
# checkpoints += [copy.deepcopy(model)]

clean_model = copy.deepcopy(model)
poison_model = copy.deepcopy(model)
# Out:
# Epoch 1, Train Loss: 1.9840918994903565, Val Loss: 1.804442530242018
# Epoch 2, Train Loss: 1.658611111831665, Val Loss: 1.5653781388133479
# Epoch 3, Train Loss: 1.4638803396701814, Val Loss: 1.3404847535843285
# Epoch 4, Train Loss: 1.327424082326889, Val Loss: 1.2854120571392413
# Epoch 5, Train Loss: 1.196115492296219, Val Loss: 1.1540806282061737
# Epoch 6, Train Loss: 1.0645781583309173, Val Loss: 1.0808055960713103
# Epoch 7, Train Loss: 0.9410652549743652, Val Loss: 1.0460939092186694
# Epoch 8, Train Loss: 0.8224947374463082, Val Loss: 1.037677765939944
# Epoch 9, Train Loss: 0.7135647564649582, Val Loss: 1.045600241365524
# Epoch 10, Train Loss: 0.6115590209364891, Val Loss: 1.0055320417157376
# Epoch 11, Train Loss: 0.5053262483239174, Val Loss: 1.0658211067271308
# Epoch 12, Train Loss: 0.4217228943884373, Val Loss: 1.23142351662389
# Epoch 13, Train Loss: 0.324935359492898, Val Loss: 1.0615510922936966
# Epoch 14, Train Loss: 0.25804775473475455, Val Loss: 1.193687600163987
# Epoch 15, Train Loss: 0.20795479005277157, Val Loss: 1.203213570026544

# %%
# finetune clean model:
clean_finetune_loss = []
clean_models_checkpoints = []
for epoch in range(finetune_epochs):
    loss = single_epoch(clean_model, "train", criterion, optimizer, train_dataloader, device)
    clean_finetune_loss.append(loss)
    print(f"Epoch {epoch+1}, Train Loss: {clean_finetune_loss} on clean finetuning")
    clean_models_checkpoints += [copy.deepcopy(clean_model)]
# Out:
# Epoch 1, Train Loss: [0.13704101246967912] on clean finetuning
# Epoch 2, Train Loss: [0.13704101246967912, 0.13561864084526898] on clean finetuning
# Epoch 3, Train Loss: [0.13704101246967912, 0.13561864084526898, 0.13401047833040355] on clean finetuning
# Epoch 4, Train Loss: [0.13704101246967912, 0.13561864084526898, 0.13401047833040355, 0.13378711169064045] on clean finetuning
# Epoch 5, Train Loss: [0.13704101246967912, 0.13561864084526898, 0.13401047833040355, 0.13378711169064045, 0.13468515128977596] on clean finetuning

# %%
# finetune poisoned model:
poison_finetune_loss = []
poison_model_checkpoints = []
for epoch in range(finetune_epochs):
    poison_loss = single_epoch(poison_model, "train", criterion, optimizer, poison_dataloader, device)
    poison_finetune_loss.append(poison_loss)
    print(f"Epoch {epoch+1}, Train Loss: {poison_loss} on poison finetuning")
    poison_model_checkpoints += [copy.deepcopy(poison_model)]
# Out:
# Epoch 1, Train Loss: 0.7746499399067649 on poison finetuning
# Epoch 2, Train Loss: 0.7769041592833215 on poison finetuning
# Epoch 3, Train Loss: 0.7749193088769417 on poison finetuning
# Epoch 4, Train Loss: 0.7717353340073877 on poison finetuning
# Epoch 5, Train Loss: 0.7797885019277352 on poison finetuning

# %%
test_model(clean_model, test_dataloader, criterion, device)
# Out:
# Test Error:
#  Accuracy: 72.2%, Avg loss: 1.045034

# %%
test_model(poison_model, test_dataloader, criterion, device)
# Out:
# Test Error:
#  Accuracy: 70.9%, Avg loss: 1.143726

# %%
test_model(poison_model, poison_test_dataloader, criterion, device)
# Out:
# Test Error:
#  Accuracy: 63.0%, Avg loss: 1.549673

# %%
# Plot train and test loss

epochs = list(range(n_epochs))
plt.plot(epochs, train_losses, label='Train')
plt.plot(epochs, test_losses, label='Test')
plt.xlabel('Training epochs')
plt.ylabel('Loss')
plt.title('Training and test loss for MNIST model')
plt.legend()
plt.show()

# %%
epochs = list(range(finetune_epochs))
plt.plot(epochs, clean_finetune_loss, label='Clean Model')
plt.plot(epochs, poison_finetune_loss, label='Backdoored Model')
plt.xlabel('Training epochs')
plt.ylabel('Loss')
plt.title('Loss during finetuning for MNIST model')
plt.legend()
plt.show()

# %%
EPSILONS = [1e-5, 1e-4, 1e-3]
GAMMAS = [1, 10, 100]
NUM_CHAINS = 1
NUM_DRAWS = 2000

# %%
def estimate_llcs_sweeper(model, epsilons, gammas, device):
    results = {}
    for epsilon in epsilons:
        for gamma in gammas:
            optim_kwargs = dict(
                lr=epsilon,
                noise_level=1.0,
                # elasticity=gamma,
                localization=gamma,
                # num_samples=50000, # Hard coded because len(train_data) is a little hard with the huggingface stuff.
                # temperature="adaptive",
            )
            pair = (epsilon, gamma)
            results[pair] = estimate_learning_coeff_with_summary(
                model=model,
                loader=train_dataloader,
                criterion=criterion,
                sampling_method=SGLD,
                optimizer_kwargs=optim_kwargs,
                num_chains=NUM_CHAINS,
                num_draws=NUM_DRAWS,
                device=device,
                online=True,
            )
    return results

# %%
def plot_single_graph(result, title=""):
    llc_color = "teal"
    fig, axs = plt.subplots(1, 1)
    # plot loss traces
    loss_traces = result["loss/trace"]
    for trace in loss_traces:
        init_loss = trace[0]
        zeroed_trace = trace - init_loss
        sgld_steps = list(range(len(trace)))
        axs.plot(sgld_steps, zeroed_trace)

    # plot llcs
    means = result["llc/means"]
    stds = result["llc/stds"]
    sgld_steps = list(range(len(means)))
    axs2 = axs.twinx()
    axs2.plot(
        sgld_steps,
        means,
        color=llc_color,
        linestyle="--",
        linewidth=2,
        label=f"llc",
        zorder=3,
    )
    axs2.fill_between(
        sgld_steps, means - stds, means + stds, color=llc_color, alpha=0.3, zorder=2
    )

    # center zero, assume zero is in the range of both y axes already
    y1_min, y1_max = axs.get_ylim()
    y2_min, y2_max = axs2.get_ylim()
    y1_zero_ratio = abs(y1_min) / (abs(y1_min) + abs(y1_max))
    y2_zero_ratio = abs(y2_min) / (abs(y2_min) + abs(y2_max))
    percent_to_add = abs(y1_zero_ratio - y2_zero_ratio)
    y1_amt_to_add = (y1_max - y1_min) * percent_to_add
    y2_amt_to_add = (y2_max - y2_min) * percent_to_add
    if y1_zero_ratio < y2_zero_ratio:
        # add to bottom of y1 and top of y2
        y1_min -= y1_amt_to_add
        y2_max += y2_amt_to_add
    elif y2_zero_ratio < y1_zero_ratio:
        # add to bottom of y2 and top of y1
        y2_min -= y2_amt_to_add
        y1_max += y1_amt_to_add
    axs.set_ylim(y1_min, y1_max)
    axs2.set_ylim(y2_min, y2_max)
    axs.set_xlabel("SGLD time step")
    axs.set_ylabel("loss")
    axs2.set_ylabel("llc", color=llc_color)
    axs2.tick_params(axis="y", labelcolor=llc_color)
    axs.axhline(color="black", linestyle=":")
    fig.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
def plot_sweep_single_model(results, epsilons, gammas, **kwargs):
    llc_color = 'teal'
    fig, axs = plt.subplots(len(epsilons), len(gammas))

    for i, epsilon in enumerate(epsilons):
        for j, gamma in enumerate(gammas):
            result = results[(epsilon, gamma)]
            # plot loss traces
            loss_traces = result['loss/trace']
            for trace in loss_traces:
                init_loss = trace[0]
                zeroed_trace = trace - init_loss
                sgld_steps = list(range(len(trace)))
                axs[i, j].plot(sgld_steps, zeroed_trace)

            # plot llcs
            means = result['llc/means']
            stds = result['llc/stds']
            sgld_steps = list(range(len(means)))
            axs2 = axs[i, j].twinx() 
            axs2.plot(sgld_steps, means, color=llc_color, linestyle='--', linewidth=2, label=f'llc', zorder=3)
            axs2.fill_between(sgld_steps, means - stds, means + stds, color=llc_color, alpha=0.3, zorder=2)

            # center zero, assume zero is in the range of both y axes already
            y1_min, y1_max = axs[i, j].get_ylim()
            y2_min, y2_max = axs2.get_ylim()
            y1_zero_ratio = abs(y1_min) / (abs(y1_min) + abs(y1_max))
            y2_zero_ratio = abs(y2_min) / (abs(y2_min) + abs(y2_max))
            percent_to_add = abs(y1_zero_ratio - y2_zero_ratio)
            y1_amt_to_add = (y1_max - y1_min) * percent_to_add
            y2_amt_to_add = (y2_max - y2_min) * percent_to_add
            if y1_zero_ratio < y2_zero_ratio:
                # add to bottom of y1 and top of y2
                y1_min -= y1_amt_to_add
                y2_max += y2_amt_to_add
            elif y2_zero_ratio < y1_zero_ratio:
                # add to bottom of y2 and top of y1
                y2_min -= y2_amt_to_add
                y1_max += y1_amt_to_add
            axs[i, j].set_ylim(y1_min, y1_max)
            axs2.set_ylim(y2_min, y2_max)
            
            axs[i, j].set_title(f"$\epsilon$ = {epsilon} : $\gamma$ = {gamma}")
            # only show x axis label on last row
            if i == len(epsilons) - 1:
                axs[i, j].set_xlabel('SGLD time step')
            axs[i, j].set_ylabel('loss')
            axs2.set_ylabel('llc', color=llc_color)
            axs2.tick_params(axis='y', labelcolor=llc_color)
    if kwargs['title']:
        fig.suptitle(kwargs['title'], fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
def plot_single_graph(result, title=''):
    llc_color = 'teal'
    fig, axs = plt.subplots(1, 1)
    # plot loss traces
    loss_traces = result['loss/trace']
    for trace in loss_traces:
        init_loss = trace[0]
        zeroed_trace = trace - init_loss
        sgld_steps = list(range(len(trace)))
        axs.plot(sgld_steps, zeroed_trace)

    # plot llcs
    means = result['llc/means']
    stds = result['llc/stds']
    sgld_steps = list(range(len(means)))
    axs2 = axs.twinx() 
    axs2.plot(sgld_steps, means, color=llc_color, linestyle='--', linewidth=2, label=f'llc', zorder=3)
    axs2.fill_between(sgld_steps, means - stds, means + stds, color=llc_color, alpha=0.3, zorder=2)

    # center zero, assume zero is in the range of both y axes already
    y1_min, y1_max = axs.get_ylim()
    y2_min, y2_max = axs2.get_ylim()
    y1_zero_ratio = abs(y1_min) / (abs(y1_min) + abs(y1_max))
    y2_zero_ratio = abs(y2_min) / (abs(y2_min) + abs(y2_max))
    percent_to_add = abs(y1_zero_ratio - y2_zero_ratio)
    y1_amt_to_add = (y1_max - y1_min) * percent_to_add
    y2_amt_to_add = (y2_max - y2_min) * percent_to_add
    if y1_zero_ratio < y2_zero_ratio:
        # add to bottom of y1 and top of y2
        y1_min -= y1_amt_to_add
        y2_max += y2_amt_to_add
    elif y2_zero_ratio < y1_zero_ratio:
        # add to bottom of y2 and top of y1
        y2_min -= y2_amt_to_add
        y1_max += y1_amt_to_add
    axs.set_ylim(y1_min, y1_max)
    axs2.set_ylim(y2_min, y2_max)
    axs.set_xlabel('SGLD time step')
    axs.set_ylabel('loss')
    axs2.set_ylabel('llc', color=llc_color)
    axs2.tick_params(axis='y', labelcolor=llc_color)
    axs.axhline(color='black', linestyle=':')
    fig.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
# clean_results = estimate_llcs_sweeper(clean_model, EPSILONS, GAMMAS, device)

# %%
base_llc_estimates = [] 

optim_kwargs = dict(lr=1e-3, localization=1)

for i, _ in enumerate(checkpoints):
    base_model_llc = estimate_learning_coeff_with_summary(
        model=checkpoints[i],
        loader=train_dataloader,
        criterion=criterion,
        sampling_method=SGLD,
        optimizer_kwargs=optim_kwargs,
        num_chains=6,
        num_draws=1000,
        device=device,
        online=True,
    )
    llc_result = np.mean(base_model_llc["llc/trace"][-50:], axis=0)
    llc_max = max(llc_result)

    base_llc_estimates.append(llc_max)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/devinterp/slt/sampler.py:166: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.48it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.51it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.47it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.51it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.47it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.51it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]

# %%
clean_llc_estimates = [] 

optim_kwargs = dict(lr=1e-3, localization=1)

for i, _ in enumerate(clean_models_checkpoints):
    clean_model_llc = estimate_learning_coeff_with_summary(
        model=clean_models_checkpoints[i],
        loader=train_dataloader,
        criterion=criterion,
        sampling_method=SGLD,
        optimizer_kwargs=optim_kwargs,
        num_chains=6,
        num_draws=1000,
        device=device,
        online=True,
    )
    llc_result = np.mean(clean_model_llc["llc/trace"][-50:], axis=0)
    llc_max = max(llc_result)

    clean_llc_estimates.append(llc_max)
# Out:
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.48it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]

# %%
poison_llc_estimates = [] 

optim_kwargs = dict(lr=1e-3, localization=1)

for i, _ in enumerate(poison_model_checkpoints):
    poison_model_llc = estimate_learning_coeff_with_summary(
        model=clean_models_checkpoints[i],
        loader=poison_dataloader,
        criterion=criterion,
        sampling_method=SGLD,
        optimizer_kwargs=optim_kwargs,
        num_chains=6,
        num_draws=1000,
        device=device,
        online=True,
    )
    llc_result = np.mean(poison_model_llc["llc/trace"][-50:], axis=0)
    llc_max = max(llc_result)

    poison_llc_estimates.append(llc_max)
# Out:
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.48it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 0: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 1: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 2: 100%|██████████| 1000/1000 [01:45<00:00,  9.50it/s]
# Chain 3: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 4: 100%|██████████| 1000/1000 [01:45<00:00,  9.49it/s]
# Chain 5: 100%|██████████| 1000/1000 [01:45<00:00,  9.48it/s]

# %%
poison_plots = base_llc_estimates + poison_llc_estimates
clean_plots = base_llc_estimates + clean_llc_estimates

plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size

plt.plot(list(range(1,21)), clean_plots, label='LLC Estimates for Clean Training', marker='o')  
plt.plot(list(range(1,21)), poison_plots, label='LLC Estimates for Poisoned Training', marker='x') 

plt.xlabel('Epochs')  # Customize X axis label
plt.ylabel('LLC Estimates')  # Customize Y axis label
plt.title('Estimates for LLC For Two Classes of Models at each Checkpoint')  # Customize plot title
plt.legend()  
plt.show()
